# %%
import pandas as pd

# %%
df = pd.read_csv(r'best_schedule.csv')

# %%
df.head()
# Out:
#                 Team1              Team2            Venue        Day  \
# 0   Tottenham Hotspur   Newcastle United     Old Trafford     Friday
# 1    Newcastle United       Leeds United          Anfield     Friday
# 2   Manchester United            Chelsea     Old Trafford   Saturday
# 3             Chelsea   Newcastle United  Stamford Bridge     Monday
# 4   Manchester United    West Ham United          Anfield     Sunday
# 5   Tottenham Hotspur       Leeds United  Stamford Bridge   Thursday
# 6     Manchester City    West Ham United   Etihad Stadium     Friday
# 7             Chelsea        Aston Villa          Anfield    Tuesday
# 8     Manchester City  Tottenham Hotspur          Anfield  Wednesday
# 9         Aston Villa    West Ham United   Etihad Stadium     Friday
# 10  Manchester United   Newcastle United          Anfield   Thursday
# 11            Chelsea  Tottenham Hotspur     Old Trafford     Friday
# 12  Manchester United            Arsenal  Stamford Bridge     Friday
# 13    Manchester City   Newcastle United     Old Trafford   Thursday
# 14            Arsenal        Aston Villa          Anfield   Saturday
# 15  Manchester United       Leeds United  Stamford Bridge     Sunday
# 16          Liverpool   Newcastle United   Etihad Stadium  Wednesday
# 17    Manchester City            Arsenal  Stamford Bridge     Monday
# 18        Aston Villa       Leeds United   Etihad Stadium   Saturday
# 19  Manchester United    Manchester City   Etihad Stadium     Friday
# 20            Arsenal  Tottenham Hotspur  Stamford Bridge     Sunday
# 21            Arsenal    West Ham United     Old Trafford   Thursday
# 22          Liverpool        Aston Villa     Old Trafford     Friday
# 23    Manchester City          Liverpool     Old Trafford     Monday
# 24   Newcastle United        Aston Villa  Stamford Bridge     Friday
# 25          Liverpool       Leeds United   Etihad Stadium   Saturday
# 26   Newcastle United    West Ham United  Stamford Bridge  Wednesday
# 27  Tottenham Hotspur        Aston Villa  Stamford Bridge    Tuesday
# 28            Arsenal   Newcastle United   Etihad Stadium    Tuesday
# 29  Manchester United          Liverpool     Old Trafford     Friday
# 30       Leeds United    West Ham United   Etihad Stadium     Friday
# 31          Liverpool    West Ham United   Etihad Stadium     Sunday
# 32    Manchester City        Aston Villa          Anfield   Saturday
# 33    Manchester City       Leeds United          Anfield     Sunday
# 34            Chelsea    West Ham United  Stamford Bridge   Saturday
# 35    Manchester City            Chelsea   Etihad Stadium  Wednesday
# 36          Liverpool            Arsenal     Old Trafford  Wednesday
# 37            Chelsea       Leeds United     Old Trafford  Wednesday
# 38  Tottenham Hotspur    West Ham United          Anfield    Tuesday
# 39            Arsenal       Leeds United          Anfield   Saturday
# 40          Liverpool  Tottenham Hotspur   Etihad Stadium    Tuesday
# 41  Manchester United  Tottenham Hotspur          Anfield     Friday
# 42  Manchester United        Aston Villa   Etihad Stadium     Monday
# 43            Chelsea            Arsenal  Stamford Bridge     Friday
# 44          Liverpool            Chelsea     Old Trafford    Tuesday
#
#       Time Slot  Week
# 0   19:00-21:00     8
# 1   11:30-13:30     5
# 2   14:00-16:00     5
# 3   11:30-13:30     8
# 4   19:00-21:00     1
# 5   16:30-18:30     4
# 6   11:30-13:30     7
# 7   19:00-21:00     1
# 8   19:00-21:00     5
# 9   19:00-21:00     6
# 10  19:00-21:00     3
# 11  11:30-13:30     6
# 12  16:30-18:30     6
# 13  11:30-13:30     1
# 14  16:30-18:30     8
# 15  19:00-21:00     3
# 16  19:00-21:00     7
# 17  19:00-21:00     7
# 18  14:00-16:00     1
# 19  19:00-21:00     2
# 20  16:30-18:30     4
# 21  11:30-13:30     4
# 22  19:00-21:00     2
# 23  09:00-11:00     1
# 24  16:30-18:30     4
# 25  09:00-11:00     7
# 26  14:00-16:00     2
# 27  11:30-13:30     3
# 28  11:30-13:30     6
# 29  09:00-11:00     4
# 30  11:30-13:30     8
# 31  11:30-13:30     5
# 32  14:00-16:00     5
# 33  14:00-16:00     4
# 34  19:00-21:00     3
# 35  19:00-21:00     4
# 36  14:00-16:00     5
# 37  14:00-16:00     7
# 38  11:30-13:30     7
# 39  09:00-11:00     2
# 40  16:30-18:30     8
# 41  14:00-16:00     7
# 42  14:00-16:00     8
# 43  19:00-21:00     1
# 44  19:00-21:00     2

# %%
day_to_index = {
    "Monday": 0, "Tuesday": 1, "Wednesday": 2,
    "Thursday": 3, "Friday": 4, "Saturday": 5, "Sunday": 6
}

df_team1 = df[['Week', 'Day', 'Team1']].rename(columns={'Team1': 'Team'})
df_team2 = df[['Week', 'Day', 'Team2']].rename(columns={'Team2': 'Team'})
df_all = pd.concat([df_team1, df_team2])

df_all['DayIndex'] = df_all['Day'].map(day_to_index)
df_all['AbsoluteDay'] = df_all['Week'] * 7 + df_all['DayIndex']

violation_summary = []

for team, group in df_all.groupby('Team'):
    total_matches = len(group)
    sorted_days = sorted(group['AbsoluteDay'].tolist())
    violations = 0
    for i in range(1, len(sorted_days)):
        if sorted_days[i] - sorted_days[i - 1] < 3:
            violations += 1
    violation_summary.append({
        'Team': team,
        'Matches': total_matches,
        'Violations': violations
    })

violation_df = pd.DataFrame(violation_summary).sort_values(by='Violations', ascending=False)
print(violation_df)
# Out:
#                 Team  Matches  Violations
# 0            Arsenal        9           0
# 1        Aston Villa        9           0
# 2            Chelsea        9           0
# 3       Leeds United        9           0
# 4          Liverpool        9           0
# 5    Manchester City        9           0
# 6  Manchester United        9           0
# 7   Newcastle United        9           0
# 8  Tottenham Hotspur        9           0
# 9    West Ham United        9           0

# %%
df['Venue'] = df.apply(lambda row: (row['Venue'], row['Week'], row['Day']), axis=1)

venue_usage_counts = df['Venue'].value_counts()

venue_violations = venue_usage_counts[venue_usage_counts > 1]


total_venue_violations = sum(venue_violations - 1)


violation_details = venue_violations.reset_index()
violation_details.columns = ['(Venue, Week, Day)', 'MatchesScheduled']

print(f"Total Venue Violations: {total_venue_violations}")
print(violation_details)
# Out:
# Total Venue Violations: 0
# Empty DataFrame
# Columns: [(Venue, Week, Day), MatchesScheduled]
# Index: []
